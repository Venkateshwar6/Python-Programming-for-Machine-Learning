# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([0,10])
ypoints=np.array([20,100])
print(plt.plot(xpoints,ypoints))
print(plt.show())
# Out:
# [<matplotlib.lines.Line2D object at 0x7f6160267dd0>]
# None

# %%
x=np.array([0,5])
y=np.array([0,25])
print(plt.plot(x,y,marker='P'))
print(plt.show())
# Out:
# [<matplotlib.lines.Line2D object at 0x7f61484e2450>]
# None

# %%
xpoints=np.array([1,2,6,8])
ypoints=np.array([20,8,1,10])
print(plt.plot(xpoints,ypoints))
print(plt.show())
# Out:
# [<matplotlib.lines.Line2D object at 0x7f61484c66d0>]
# None

# %%
ypoints=np.array([5,7,1,0,3])
print(plt.plot(ypoints))
print(plt.show())
# Out:
# [<matplotlib.lines.Line2D object at 0x7f61484e6150>]
# None

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(0,2*(np.pir),0.1)
y=np.sin(x)
plt.plot(x,y)
plt.show()
